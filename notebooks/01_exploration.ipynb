# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

import json
import os

# %%
df = pd.read_csv("../data/synthetic_pupillometry.csv")
df.head()
